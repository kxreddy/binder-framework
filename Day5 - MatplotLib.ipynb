# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mlb
import numpy as np

# %%
df_nta=pd.read_csv('C:\\DataFiles\\DIpandas.csv')
df_nta
# Out:
#    Neighborhood_Tabulation_Area_(NTA)_(2020)  count_of_Companies  \
# 0                                     BK0101                  78
# 1                                     BK0102                   9
# 2                                     BK0103                   7
# 3                                     BK0104                 104
# 4                                     BK0201                  11
# ..                                       ...                 ...
# 56                                    QN1303                  10
# 57                                    QN1306                  25
# 58                                    SI0106                   7
# 59                                    SI0107                  15
# 60                                    SI0204                  12
#
#     Total_jobs_created  Total_average_saving
# 0                 16.0          10367.961795
# 1                 15.0          12599.753333
# 2                  0.0          19150.922857
# ...

# %%
x=df_nta['Total_jobs_created'].tolist()
y=df_nta['Total_average_saving'].tolist()
log_y=np.log(df_nta['Total_average_saving'])
log_y=log_y.tolist()
# Out:
# C:\Users\kxred\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#Scatter plot with Standard average savings values
N = len(x)

c = np.random.randint(1, 5, size=N)
s = np.random.randint(10, 220, size=N)

fig, ax = plt.subplots(figsize=(6, 3), layout='constrained')
#ax.scatter('a', 'b', c='c', s='d', data=data)
#ax.scatter(x,log_y,c=c,s=s)
ax.scatter(x,y,c=c,s=s)
ax.set_xlabel('Total Jobs Created')
ax.set_ylabel('Total Avg Savings')
ax.set_title("Jobs Created Vs Avg Savings")  # Add a title to the axes.
#ax.legend('Total Jobs Created','Total Avg Savings')  # Add a legend.
# Out:
# Text(0.5, 1.0, 'Jobs Created Vs Avg Savings')

# %%
#Scatter plotwith log average savings values
N = len(x)

c = np.random.randint(1, 5, size=N)
s = np.random.randint(10, 220, size=N)

fig, ax = plt.subplots(figsize=(6, 3), layout='constrained')
ax.scatter(x,log_y,c=c,s=s)
#ax.scatter(x,y,c=c,s=s)
ax.set_xlabel('Total Jobs Created')
ax.set_ylabel('Total Avg Savings')
ax.set_title("Jobs Created Vs Avg Savings")  # Add a title to the axes.
#ax.legend('Total Jobs Created','Total Avg Savings')  # Add a legend.
# Out:
# Text(0.5, 1.0, 'Jobs Created Vs Avg Savings')

# %%
plt.style.use('_mpl-gallery')

# make data
#np.random.seed(1)
#x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')

ax.hist(y, bins=25, edgecolor="white")
ax.set_title("Average Savings")

plt.show()

# %%
# plot
fig, ax = plt.subplots()

line_plt.plot(linewidth=2.0)
# Out:
# <Axes: xlabel='effective_date'>

# %%
#Gneral Practice Pandas

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

# %%
dfnta_1=pd.read_csv("C:\\DataFiles\\Value_of_Energy_Cost_Savings_Program_Savings_for_Businesses_20231225.csv")
dfnta_1
# Out:
#       Period                                 Company Name     company contact  \
# 0     FY2018                         139 ACA Realty, Inc.     Eitan Chandally
# 1     FY2018  141 Lake Avenue Realty c/o JR Produce, Inc.           Josef Raz
# 2     FY2018                       14-10 123rd Street LLC  Danica/Ivan Drazic
# 3     FY2018                      183 Lorriane Street LLC        Tom Sapienza
# 4     FY2018                    21st Century Optics, Inc.     Ralph Woythaler
# ...      ...                                          ...                 ...
# 2358  FY2022           Works Manufacturing of Brooklyn NY    Aleksey Kravchuk
# 2359  FY2022              WorldWide Plumbing Supply, Inc.     Surie Lefkowitz
# 2360  FY2022                                      WPC LLC     Sara Samplawska
# 2361  FY2022                            WUD Furniture LLC      Keren Springer
# 2362  FY2022                          Wurtec Incorporated     Diego Alvaraado
#
# ...

# %%
#dfnta_1.columns=dfnta_1.columns.str.replace(' ','_')
#dfnta_1.columns=dfnta_1.columns.str.lower()
dfnta_1
# Out:
#       index  period                                 company_name  \
# 0         0  FY2018                         139 ACA Realty, Inc.
# 1         1  FY2018  141 Lake Avenue Realty c/o JR Produce, Inc.
# 2         2  FY2018                       14-10 123rd Street LLC
# 3         3  FY2018                      183 Lorriane Street LLC
# 4         4  FY2018                    21st Century Optics, Inc.
# ...     ...     ...                                          ...
# 2358   2358  FY2022           Works Manufacturing of Brooklyn NY
# 2359   2359  FY2022              WorldWide Plumbing Supply, Inc.
# 2360   2360  FY2022                                      WPC LLC
# 2361   2361  FY2022                            WUD Furniture LLC
# 2362   2362  FY2022                          Wurtec Incorporated
#
#          company_contact                      company_email company_phone  \
# 0        Eitan Chandally                  barbara@dial7.com    7187076123
# ...

# %%
group_nta=dfnta_1.groupby('neighborhood_tabulation_area_(nta)_(2020)')

# %%
group_nta.agg({'company_name':'count','job_created':'sum','total_savings':'mean'})

# %%
dfnta_1=dfnta_1.set_index('effective_date')
#dfnta_1.loc['04/07/2008']

# %%
#dfnta_1['effective_date']=pd.to_datetime(dfnta_1['effective_date'],format='%m/%d/%Y')
dfnta_1
# Out:
#                 index  period                                 company_name  \
# effective_date
# 2008-04-07          0  FY2018                         139 ACA Realty, Inc.
# 2009-12-08          1  FY2018  141 Lake Avenue Realty c/o JR Produce, Inc.
# 2011-03-04          2  FY2018                       14-10 123rd Street LLC
# 2015-11-06          3  FY2018                      183 Lorriane Street LLC
# 2009-01-07          4  FY2018                    21st Century Optics, Inc.
# ...               ...     ...                                          ...
# 2022-05-03       2358  FY2022           Works Manufacturing of Brooklyn NY
# 2018-08-03       2359  FY2022              WorldWide Plumbing Supply, Inc.
# 2022-01-03       2360  FY2022                                      WPC LLC
# 2016-01-26       2361  FY2022                            WUD Furniture LLC
# 2019-10-03       2362  FY2022                          Wurtec Incorporated
#
# ...

# %%
line_plt=dfnta_1['job_created'].resample('M').sum()
line_plt
# Out:
# effective_date
# 1993-02-28    25.0
# 1993-03-31     0.0
# 1993-04-30    10.0
# 1993-05-31     0.0
# 1993-06-30     0.0
#               ...
# 2022-02-28     0.0
# 2022-03-31     0.0
# 2022-04-30     0.0
# 2022-05-31     0.0
# 2022-06-30     0.0
# Freq: M, Name: job_created, Length: 353, dtype: float64

# %%
line_plt.plot()
# Out:
# <Axes: xlabel='effective_date'>
